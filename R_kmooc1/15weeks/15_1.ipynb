# %%
import pandas as pd
import numpy as np
iris = pd.read_csv('C:/R실습/iris.csv', encoding='CP949')

# %%
iris
type(iris)
# Out:
# pandas.core.frame.DataFrame

# %%
iris
# Out:
#       SL   SW   PL   PW    Species
# 0    5.1  3.5  1.4  0.2     setosa
# 1    4.9  3.0  1.4  0.2     setosa
# 2    4.7  3.2  1.3  0.2     setosa
# 3    4.6  3.1  1.5  0.2     setosa
# 4    5.0  3.6  1.4  0.2     setosa
# ..   ...  ...  ...  ...        ...
# 145  6.7  3.0  5.2  2.3  virginica
# 146  6.3  2.5  5.0  1.9  virginica
# 147  6.5  3.0  5.2  2.0  virginica
# 148  6.2  3.4  5.4  2.3  virginica
# 149  5.9  3.0  5.1  1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Species'], dtype='object')

# %%
iris.SL
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: SL, Length: 150, dtype: float64

# %%
iris.SW
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: SW, Length: 150, dtype: float64

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline #명령어 다음에 바로 출력될 수 있게 하는 명령어(다른 창이 아닌)
# Out:
# UsageError: unrecognized arguments: #명령어 다음에 바로 출력될 수 있게 하는 명령어(다른 창이 아닌)

# %%
# %matplotlib inline

# %%
plt.plot(iris.SL,iris.SW)

# %%
plt.plot(iris.SL)

# %%
plt.plot(iris.SL, lw=5)

# %%
plt.plot(iris.SL, 'ro')

# %%
plt.plot(iris.SL, iris.SW, 'bo')

# %%
x = [1,2,3,4,5]
plt.plot(iris.SL, x, 'bo') #요소 개수 값이 같아야 함
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-3601b6235cba> in <module>
#       1 x = [1,2,3,4,5]
# ----> 2 plt.plot(iris.SL, x, 'bo')
#
# C:\Anaconda\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2838 @_copy_docstring_and_deprecators(Axes.plot)
#    2839 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
#    2842         **({"data": data} if data is not None else {}), **kwargs)
#
# C:\Anaconda\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
# ...

# %%
plt.plot(iris.SL, iris.SW, 'b')

# %%
plt.xlim(0, np.max(iris.SL))
plt.ylim(0, np.max(iris.SW))
plt.title("붓꽃의 꽃잎 길이와 넓이 관계")
plt.plot(iris.SL, iris.SW, 'bo')
# Out:
# C:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 48531 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44867 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51086 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44600 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51060 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.xlim(0, np.max(iris.SL))
plt.ylim(0, np.max(iris.SW))
plt.title("relationship of iris length and area")
plt.plot(iris.SL, iris.SW, 'bo')

# %%
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="C:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %%
plt.title('붓꽃의 꽃잎 길이와 넓이 관계')
plt.plot(iris.SL, iris.SW, 'bo')

# %%
plt.xlabel("꽃잎 길이")
plt.ylabel("꽃잎 넓이")
plt.title('붓꽃의 꽃잎 길이와 넓이 관계')
plt.plot(iris.SL, iris.SW, 'bo')

# %%
plt.figure(figsize=(10,4))
plt.xlabel("꽃잎 길이")
plt.ylabel("꽃잎 넓이")
plt.title('붓꽃의 꽃잎 길이와 넓이 관계')
plt.plot(iris.SL, iris.SW, 'bo')

# %%
plt.figure(figsize=(10,4))
plt.plot(iris.SL, lw=1.5, label="꽃받침")
plt.plot(iris.PL, lw=1.5, label="꽃잎")
plt.legend(loc=3)

# %%
plt.figure(figsize=(10,4))
plt.plot(iris.SL, 'ro', label="꽃받침")
plt.plot(iris.PL, 'bo', label="꽃잎")
plt.legend(loc=4)
plt.grid(True)

# %%
plt.figure(figsize=(10,10))
plt.subplot(211)
plt.plot(iris.SL, 'ro', label="꽃받침")
plt.title("꽃받침길이 분포")

plt.subplot(212)
plt.plot(iris.PL, 'bo', label="꽃잎")
plt.title("꽃받침길이 분포")
# Out:
# Text(0.5, 1.0, '꽃받침길이 분포')

# %%
plt.figure(figsize=(10,10))
plt.subplot(221)
plt.plot(iris.SL, 'ro')
plt.title("꽃받침길이 분포")

plt.subplot(222)
plt.plot(iris.PL, 'bo')
plt.title("꽃잎길이 분포")

plt.subplot(223)
plt.plot(iris.SW, lw=5)
plt.title("꽃받침넓이 분포")

plt.subplot(224)
plt.plot(iris.PW, lw=2)
plt.title("꽃잎 넓이 분포")
# Out:
# Text(0.5, 1.0, '꽃잎 넓이 분포')
